# %% [markdown]
# ## Ejercicios de pair programming 3 enero: Limpieza II

# %% [markdown]
# 1.Columna de species: si exploramos esta columna en detalle nos podemos dar cuenta que tenemos muchos valores únicos y esto hace que sea muy difícil trabajar con esta columna. Lo que vamos a hacer es clasificar los tiburones en 5 especies diferentes, las más comunes, que incluyen el tiburón blanco (White), el tiburón tigre (Tiger ), el tiburón gris (Grey), el tiburón limón (Lemon) y el tiburón toro (Bull). El resto de las especies las incluiremos en un único grupo que podremos llamar "Unspecified". Ahora nos podemos sentir un poco abrumadas y no saber como enfrentarnos a este reto, pero don't worry, os dejamos por aquí unas 💡 pistas 💡 para que os ayuden a entender cómo hacerlo.
# Los valores de las columnas son strings por lo que podremos usar regex para buscar palabras clave en cada celda y asignarlo a una de las categorías que hemos definido previamente.
#
#  imaginemos que el valor de una celda es el siguiente
#
# 'White shark, 3.5 m'
#
# tendremos que buscar el patrón de regex que nos permita extraer White shark de ese string y que nos devuelva solo White shark.
#
# Un patrón que podriamos usar es:
#
# patron_blanco = r".*[Ww](hite|HITE).*" # esto podría ser así porque puede estar en mayúsculas o en minúsculas.
#
# de la misma forma que hemos sacado el patron para el tiburón blanco, tendremos que sacar los patrones para las otras 4 especies que queremos "encontrar".
# Tendremos que crearnos una función que aplicaremos sobre nuestra columna species para que nos devuelva una nueva columna con los valores clasificados en función de los patrones de regex que hayamos definido.

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import regex as re

pd.options.display.max_columns = None

# %%
df = pd.read_csv("../datos/tiburon5.csv", index_col=0)

# %%
df.head()
# Out:
#     case_number  year        type    country        activity age  \
# 0    2018.06.25  2018     Boating        usa        Paddling  57
# 1  2018.06.03.a  2018  Unprovoked     brazil        Swimming  18
# 2  2018.05.26.b  2018  Unprovoked        usa         Walking  15
# 3    2018.05.24  2018    Provoked  australia  Feeding sharks  32
# 4  2018.05.13.a  2018     Invalid    england         Fishing  21
#
#            species_                                             injury  mes  \
# 0       White shark  No injury to occupant, outrigger canoe and pad...  Jun
# 1       Tiger shark                                              FATAL  Jun
# 2    Bull shark, 6'                              Lower left leg bitten  May
# 3   Grey reef shark  Minor bite to hand by captive shark. PROVOKED ...  May
# 4  Invalid incident  Injured by teeth of a dead porbeagle shark he ...  May
#
#   deceso genero
# 0      N      F
# 1      Y      M
# 2      N      M
# 3      N      M
# 4      N      M

# %%
df["species_"].value_counts()
# Out:
# White shark                                                                                                                      76
# Tiger shark                                                                                                                      37
# 4' shark                                                                                                                         34
# Bull shark                                                                                                                       32
# Shark involvement not confirmed                                                                                                  26
#                                                                                                                                  ..
# 1.2 m [4'] blacktip or sandbar shark                                                                                              1
# Bull shark, 1.8 m to 2.1 m [6' to 7']                                                                                             1
# Mako shark, 400-lb                                                                                                                1
# 1.2 m to 1.5 m [4' to 5'] shark, possibly a bull shark                                                                            1
# Said to involve a grey nurse shark that leapt out of the water and  seized the boy but species identification is questionable     1
# Name: species_, Length: 856, dtype: int64

# %%
df.dtypes
# Out:
# case_number    object
# year            int64
# type           object
# country        object
# activity       object
# age            object
# species_       object
# injury         object
# mes            object
# deceso         object
# genero         object
# dtype: object

# %%
df.isnull().sum()
# Out:
# case_number      0
# year             0
# type             0
# country         10
# activity        31
# age            154
# species_       126
# injury           8
# mes            154
# deceso          99
# genero          14
# dtype: int64

# %%
patron_blanco = ".*[Ww](hite|HITE).*"
patron_tigre = ".*[Tt](iger|IGER).*"
patron_gris = ".*[Gg](rey|REY).*"
patron_toro = ".*[Bb](ull|ULL).*"
patron_limon = ".*[Ll](emon|EMON).*"

# %%
def sacar_especies (col):

    if re.findall(patron_blanco, str(col)) :
        return "White"
    elif re.findall(patron_tigre, str(col)) :
        return "Tiger"
    elif re.findall(patron_gris, str(col)):
        return "Grey"
    elif re.findall(patron_toro, str(col)) :
        return "Bull"
    elif re.findall(patron_limon, str(col)):
        return "Lemon"
    else:
        return "Unspecified"

# %%
df["especies"] = df["species_"].apply(sacar_especies)

# %%
df.head(10)
# Out:
#     case_number  year        type       country        activity age  \
# 0    2018.06.25  2018     Boating           usa        Paddling  57
# 1  2018.06.03.a  2018  Unprovoked        brazil        Swimming  18
# 2  2018.05.26.b  2018  Unprovoked           usa         Walking  15
# 3    2018.05.24  2018    Provoked     australia  Feeding sharks  32
# 4  2018.05.13.a  2018     Invalid       england         Fishing  21
# 5  2018.04.28.b  2018  Unprovoked    costa rica    Scuba diving  30
# 6  2018.04.25.a  2018  Unprovoked     australia         Surfing  60
# 7    2018.04.23  2018  Unprovoked      maldives         Fishing  32
# 8    2018.04.22  2018  Unprovoked  south africa   Paddle-skiing  33
# 9    2018.04.03  2018  Unprovoked  south africa         Surfing  19
#
#              species_                                             injury  mes  \
# 0         White shark  No injury to occupant, outrigger canoe and pad...  Jun
# 1         Tiger shark                                              FATAL  Jun
# 2      Bull shark, 6'                              Lower left leg bitten  May
# 3     Grey reef shark  Minor bite to hand by captive shark. PROVOKED ...  May
# 4    Invalid incident  Injured by teeth of a dead porbeagle shark he ...  May
# 5         Tiger shark                    No injury, shark bit scuba gear  Apr
# 6           3 m shark              No injury, knocked off board by shark  Apr
# 7         Tiger shark                                 5-inch cut to hand  Apr
# 8  White shark, 2.5 m                   No injury, shark bit hole in ski  Apr
# 9         White shark               Lacerations to left knee & lower leg  Apr
#
#   deceso genero     especies
# 0      N      F        White
# 1      Y      M        Tiger
# 2      N      M         Bull
# 3      N      M         Grey
# 4      N      M  Unspecified
# 5      N      M        Tiger
# 6      N      M  Unspecified
# 7      N      M        Tiger
# 8      N      M        White
# 9      N      M        White

# %% [markdown]
# 2.Columna de age: es una columna de tipo string pero debería ser de tipo integer. Además, en esta columna nos vamos a encontrar con algunos errores tipográficos, estos incluyen:
#
# Edad en formato string
#
# Edades separadas por &, or, to, >
#
# Edades con ?
#
# Vamos con algunas 💡 pistas 💡 para que os ayuden a entender cómo hacerlo:
#
# Primero tendremos que eliminar todos esos símbolos especiales que nos aparecen. De nuevo, podremos usar regex para extraer unicamente los números que es lo que nos interesa. Usar este regex en una función para sacar solo los números.
#
# Puede que os salga un error similar a este:
#
# TypeError: expected string or bytes-like object
#
# Para solucionar este problema, antes de nada tendréis que ejecutar este código para que no os de error:
#
# df['nombre_columna'] = df['nombre_columna'].astype(str)
#
# Una vez que hayáis extraido los números, os daréis cuenta que hay celdas que tienen más de una edad. Tendréis que decidir que hacer en esos casos. Os dejamos por aquí una posible opción usando un método de Pandas que os puede resultar super útil. El método explode, aqui.
#
# Por último cambiad el tipo de la columna de string a integer.

# %% [markdown]
# 3. Guarda el csv con las columnas limpias para seguir trabajando con este dataframe limpio.

# %%
df.to_csv("../datos/tiburon.csv")
